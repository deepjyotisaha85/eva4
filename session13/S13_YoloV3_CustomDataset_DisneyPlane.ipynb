# %% [markdown]
# <a href="https://colab.research.google.com/github/deepjyotisaha85/eva4/blob/master/session13/S13_YoloV3_CustomDataset_DisneyPlane.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/deepjyotisaha85/YoloV3.git
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (160/160), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 160 (delta 8), reused 155 (delta 7), pack-reused 0
# Receiving objects: 100% (160/160), 12.74 MiB | 6.84 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls
# Out:
# gdrive	sample_data  YoloV3

# %%
# !ls "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13"
# Out:
# S13_YoloV3_CustomDataset_Plane.ipynb  seed-data-plane

# %%
# !ls "/content/YoloV3"
# Out:
#  annotation_tool   output	  results.txt	     train.py
#  cfg		   __pycache__	  test_batch0.png   'ubdivisions=1'
#  data		   README.md	  test.py	     utils
#  detect.py	   results.json   ting		     vim.exe.stackdump
#  models.py	   results.png	  train_batch0.png   weights

# %%
# !rm -rf "/content/YoloV3/data/customdata/images/"
# !rm -rf "/content/YoloV3/data/customdata/labels/"

# %%
# !cp "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/yolov3-spp-ultralytics.pt" "/content/YoloV3/weights/"

# %%
#!cp -r "/content/gdrive/My Drive/Colab Notebooks/EVA4/Session 13/seed-data/images/" "/content/YoloV3/data/customdata/"

# %%
#!cp -r "/content/gdrive/My Drive/Colab Notebooks/EVA4/Session 13/seed-data/labels/" "/content/YoloV3/data/customdata/"

# %%
#!cp -R "/content/gdrive/My Drive/Colab Notebooks/EVA4/Session 13/seed-data/custom.names" "/content/YoloV3/data/customdata/"

# %%
#!cp -R "/content/gdrive/My Drive/Colab Notebooks/EVA4/Session 13/seed-data/custom.txt" "/content/YoloV3/data/customdata/"

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla K80', major=3, minor=7, total_memory=11441MB, multi_processor_count=13)

# %%
ls
# Out:
# gdrive/  sample_data/  YoloV3/

# %%
cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !ls
# Out:
#  annotation_tool   output	  results.txt	     train.py
#  cfg		   __pycache__	  test_batch0.png   'ubdivisions=1'
#  data		   README.md	  test.py	     utils
#  detect.py	   results.json   ting		     vim.exe.stackdump
#  models.py	   results.png	  train_batch0.png   weights

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=3, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# 2020-04-25 09:45:36.836510: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 4694.77it/s]
# Caching images (0.0GB): 100% 20/20 [00:00<00:00, 95.53it/s]
# ...

# %%
# !cp -r "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/images/" "/content/YoloV3/data/customdata/"
# !cp -r "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/labels/" "/content/YoloV3/data/customdata/"
# !cp -R "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/custom.names" "/content/YoloV3/data/customdata/"
# !cp -R "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/custom.txt" "/content/YoloV3/data/customdata/"
# !cp -R "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/custom.data" "/content/YoloV3/data/customdata/"
# !cp -R "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/yolov3-custom.cfg" "/content/YoloV3/cfg/"

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# 2020-04-25 09:51:06.782952: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25841e+07 parameters, 6.25841e+07 gradients
# Caching labels (152 found, 0 missing, 0 empty, 0 duplicate, for 152 images): 100% 152/152 [00:00<00:00, 5561.14it/s]
# Caching images (0.1GB): 100% 152/152 [00:01<00:00, 96.59it/s]
# Reading image shapes: 100% 152/152 [00:00<00:00, 6030.75it/s]
# ...

# %%
# !python detect.py --conf-thres 0.1 --output out_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Model Summary: 225 layers, 6.25841e+07 parameters, 6.25841e+07 gradients
# image 1/152 data/customdata/images/img001.jpg: 384x512 1 fighter planes, Done. (0.085s)
# image 2/152 data/customdata/images/img002.jpg: 384x512 1 fighter planes, Done. (0.078s)
# image 3/152 data/customdata/images/img003.jpg: 384x512 1 fighter planes, Done. (0.075s)
# image 4/152 data/customdata/images/img004.jpg: 384x512 1 fighter planes, Done. (0.070s)
# image 5/152 data/customdata/images/img005.jpg: 384x512 1 fighter planes, Done. (0.068s)
# ...

# %%
Image(filename='out_out/img001.jpg', width=600)

# %%
Image(filename='out_out/img002.jpg', width=600)

# %%
Image(filename='out_out/img003.jpg', width=600)

# %%
Image(filename='out_out/img020.jpg', width=600)

# %%
# !python3 detect.py --weights weights/last.pt  --cfg "cfg/yolov3-custom.cfg" --names data/customdata/custom.names --source "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/Disney_Planes_1.mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='output', save_txt=False, source='/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/Disney_Planes_1.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Model Summary: 225 layers, 6.25841e+07 parameters, 6.25841e+07 gradients
# video 1/1 (1/2111) /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/Disney_Planes_1.mp4: 320x512 Done. (0.078s)
# video 1/1 (2/2111) /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/Disney_Planes_1.mp4: 320x512 Done. (0.071s)
# video 1/1 (3/2111) /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/Disney_Planes_1.mp4: 320x512 Done. (0.069s)
# ...

# %%
# !cp -r "/content/YoloV3/output/Disney_Planes_1.mp4" "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/Disney_Planes_1_Processed.mp4"

# %%
# !python3 detect.py --weights weights/last.pt  --cfg "cfg/yolov3-custom.cfg" --names data/customdata/custom.names --source "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/Disney_Planes_2.mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='output', save_txt=False, source='/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/Disney_Planes_2.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Model Summary: 225 layers, 6.25841e+07 parameters, 6.25841e+07 gradients
# video 1/1 (1/4316) /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/Disney_Planes_2.mp4: 320x512 Done. (0.090s)
# video 1/1 (2/4316) /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/Disney_Planes_2.mp4: 320x512 Done. (0.076s)
# video 1/1 (3/4316) /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/Disney_Planes_2.mp4: 320x512 Done. (0.071s)
# ...

# %%
# !cp -r "/content/YoloV3/output/Disney_Planes_2.mp4" "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/seed-data-plane/Disney_Planes_2_Processed.mp4"
